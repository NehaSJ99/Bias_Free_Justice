# %% [markdown]
# ## Data Augmentation using few-shot learning
#
# - Here we will try to target the imbalance in our data leveraging state of the art few shot learning technique with LLM
#
# - We are using Langchain to achieve this. The main advantage of generating synthetic data with LLM over traditional techniques like SMOTE and ADASYN is we can customize the augmentation process without loosing the essence of the original data.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/alda project/processed_data.csv')

# %%
df.head()
# Out:
#    id              name    first       last compas_screening_date   sex  \
# 0   1  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 1   2      michael ryan  michael       ryan            31/12/2014  Male
# 2   3       kevon dixon    kevon      dixon            27/01/2013  Male
# 3   4          ed philo       ed      philo            14/04/2013  Male
# 4   5       marcu brown    marcu      brown            13/01/2013  Male
#
#           dob  age          age_cat              race  ...  \
# 0  18/04/1947   69  Greater than 45             Other  ...
# 1  06/02/1985   31          25 - 45         Caucasian  ...
# 2  22/01/1982   34          25 - 45  African-American  ...
# 3  14/05/1991   24     Less than 25  African-American  ...
# 4  21/01/1993   23     Less than 25  African-American  ...
#
#    type_of_assessment  decile_score.1  score_text  screening_date  \
# 0  Risk of Recidivism               1         Low      14/08/2013
# 1  Risk of Recidivism               5      Medium      31/12/2014
# 2  Risk of Recidivism               3         Low      27/01/2013
# 3  Risk of Recidivism               4         Low      14/04/2013
# 4  Risk of Recidivism               8        High      13/01/2013
#
#    v_type_of_assessment  v_decile_score v_score_text v_screening_date  \
# 0      Risk of Violence               1          Low       14/08/2013
# 1      Risk of Violence               2          Low       31/12/2014
# 2      Risk of Violence               1          Low       27/01/2013
# 3      Risk of Violence               3          Low       14/04/2013
# 4      Risk of Violence               6       Medium       13/01/2013
#
#   priors_count.1 event
# 0              0     0
# 1              0     0
# 2              0     1
# 3              4     0
# 4              1     0
#
# [5 rows x 48 columns]

# %%
X = df[["age", "juv_fel_count", "juv_misd_count", "juv_other_count", "priors_count", "c_charge_degree","is_recid"]]  # Features

# %%
X.is_recid.value_counts()
# Out:
# is_recid
# 0    7528
# 1    3772
# Name: count, dtype: int64

# %%
minority_data = X[X.is_recid == 1].head(4)

# %%
# Initialize an empty list to store the formatted examples
formatted_examples = []

# Iterate over each row in the DataFrame
for index, row in df.head(50).iterrows():
    # Construct the string for the current row
    example_string = f"age: {row['age']}, juv_fel_count: {row['juv_fel_count']}, juv_misd_count: {row['juv_misd_count']}, juv_other_count: {row['juv_other_count']}, priors_count: {row['priors_count']}, c_charge_degree: {row['c_charge_degree']}, is_recid: {row['is_recid']}"
    # Append the constructed string as a dictionary to the list
    formatted_examples.append({"example": f'''{example_string}'''})

# Display the formatted examples list

# %%
formatted_examples
# Out:
# [{'example': 'age: 69, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 31, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: nan, is_recid: 0'},
#  {'example': 'age: 34, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 24, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 1, priors_count: 4, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 23, juv_fel_count: 0, juv_misd_count: 1, juv_other_count: 0, priors_count: 1, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 43, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 2, c_charge_degree: (F7), is_recid: 0'},
#  {'example': 'age: 44, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 41, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 14, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 43, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 3, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 39, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 20, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 1, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 26, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 21, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (F2), is_recid: 1'},
#  {'example': 'age: 27, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 23, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 3, c_charge_degree: (M1), is_recid: 1'},
#  {'example': 'age: 37, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 22, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 41, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 47, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 31, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 7, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 37, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 25, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 3, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 31, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 6, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 31, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 5, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 64, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 13, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 21, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 27, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 1'},
#  {'example': 'age: 21, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 24, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 2, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 24, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 42, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (F1), is_recid: 0'},
#  {'example': 'age: 43, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 1, c_charge_degree: (M2), is_recid: 0'},
#  {'example': 'age: 32, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 54, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 44, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 8, c_charge_degree: (M2), is_recid: 0'},
#  {'example': 'age: 49, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: nan, is_recid: 0'},
#  {'example': 'age: 27, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 8, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 27, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 8, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 36, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 3, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 26, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 1, priors_count: 5, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 33, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 33, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 30, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 9, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 32, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 4, c_charge_degree: (F3), is_recid: 1'},
#  {'example': 'age: 63, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (M1), is_recid: 0'},
#  {'example': 'age: 27, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 2, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 55, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 29, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 0, c_charge_degree: nan, is_recid: 0'},
#  {'example': 'age: 32, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 0, priors_count: 15, c_charge_degree: (F3), is_recid: 0'},
#  {'example': 'age: 38, juv_fel_count: 0, juv_misd_count: 0, juv_other_count: 2, priors_count: 5, c_charge_degree: (F3), is_recid: 0'}]

# %%
# !pip install -U langchain langchain_experimental openai
# Out:
# Collecting langchain
#   Downloading langchain-0.1.16-py3-none-any.whl (817 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 9.3 MB/s eta 0:00:00
# Collecting langchain_experimental
#   Downloading langchain_experimental-0.0.57-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 12.1 MB/s eta 0:00:00
# Collecting openai
#   Downloading openai-1.17.1-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain)
#   Downloading langchain_community-0.0.32-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.5 MB/s eta 0:00:00
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain)
#   Downloading langchain_core-0.1.42-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 21.7 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.47-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.0/113.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.42->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.5 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, h11, typing-inspect, marshmallow, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain-community, langchain, langchain_experimental
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.4 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.16 langchain-community-0.0.32 langchain-core-0.1.42 langchain-text-splitters-0.0.1 langchain_experimental-0.0.57 langsmith-0.1.47 marshmallow-3.21.1 mypy-extensions-1.0.0 openai-1.17.1 orjson-3.10.0 packaging-23.2 typing-inspect-0.9.0

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.pydantic_v1 import BaseModel
from langchain_experimental.tabular_synthetic_data.base import SyntheticDataGenerator
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator, OPENAI_TEMPLATE
from langchain_experimental.tabular_synthetic_data.prompts import SYNTHETIC_FEW_SHOT_SUFFIX, SYNTHETIC_FEW_SHOT_PREFIX

# %%
class CriminalRecord(BaseModel):
    age: int
    juv_fel_count: int
    juv_misd_count: int
    juv_other_count: int
    priors_count: int
    c_charge_degree: str
    is_recid: int

# %%
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=formatted_examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject", "extra"],
    example_prompt=OPENAI_TEMPLATE,
)

# %%
synthetic_data_generator = create_openai_data_generator(
    output_schema=CriminalRecord,
    llm=ChatOpenAI(temperature=1),
    prompt=prompt_template,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
n_samples = 100
synthetic_results = synthetic_data_generator.generate(
    subject="CriminalRecord",
    extra="closely observe all the data samples. Don't create duplicates, try to generate good synthetic data that closely resembles the example given.",
    runs=n_samples,
)

# %%
synthetic_results
# Out:
# [CriminalRecord(age=34, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=2, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=27, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=40, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=41, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=14, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=30, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=26, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=0, c_charge_degree='F3', is_recid=0),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=37, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=0, c_charge_degree='(M1)', is_recid=0),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=38, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=28, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=25, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=0),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=37, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=2, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=2, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=0, c_charge_degree='M1', is_recid=0),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=44, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=8, c_charge_degree='(M2)', is_recid=0),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=27, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=8, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='(F3)', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=30, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=9, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=27, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=2, c_charge_degree='(F3)', is_recid=0),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=0, c_charge_degree='(F3)', is_recid=0),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=15, c_charge_degree='F3', is_recid=0),
#  CriminalRecord(age=30, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=35, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=7, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=30, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=3, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=32, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=27, juv_fel_count=0, juv_misd_count=0, juv_other_count=0, priors_count=2, c_charge_degree='F3', is_recid=0),
#  CriminalRecord(age=28, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=4, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=31, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=5, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=33, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1),
#  CriminalRecord(age=29, juv_fel_count=0, juv_misd_count=0, juv_other_count=1, priors_count=6, c_charge_degree='F3', is_recid=1)]

# %%
import pandas as pd

# Create a list of dictionaries from the objects
synthetic_data = []
for item in synthetic_results:
    synthetic_data.append({
        'age': item.age,
        'juv_fel_count': item.juv_fel_count,
        'juv_misd_count': item.juv_misd_count,
        'juv_other_count': item.juv_other_count,
        'priors_count': item.priors_count,
        'c_charge_degree': item.c_charge_degree,
        'is_recid' : item.is_recid
    })

# Create a Pandas DataFrame from the list of dictionaries
synthetic_df = pd.DataFrame(synthetic_data)

# Display the DataFrame
print(type(synthetic_df))
synthetic_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0    34              0               0                0             3
# 1    29              0               0                0             2
# 2    32              0               0                0             3
# 3    27              0               0                0             3
# 4    31              0               0                0             4
# ..  ...            ...             ...              ...           ...
# 95   27              0               0                0             2
# 96   28              0               0                1             4
# 97   31              0               0                1             5
# 98   33              0               0                1             6
# 99   29              0               0                1             6
#
#    c_charge_degree  is_recid
# 0             (F3)         1
# 1             (F3)         1
# 2             (F3)         1
# 3             (F3)         1
# 4             (F3)         1
# ..             ...       ...
# 95              F3         0
# 96              F3         1
# 97              F3         1
# 98              F3         1
# 99              F3         1
#
# [100 rows x 7 columns]

# %%
synthesized_df = pd.concat([X, synthetic_df], ignore_index=True)
